# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('D:\SberMarket'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# D:\SberMarket\notebookfa5a3adad6.ipynb
# D:\SberMarket\sample_submission.csv
# D:\SberMarket\sample_submission.csv.zip
# D:\SberMarket\tab_4_user_profiles.csv
# D:\SberMarket\tab_4_user_profiles.csv.zip
# D:\SberMarket\tab_6_city.csv
# D:\SberMarket\test-recsys.zip
# D:\SberMarket\.ipynb_checkpoints\notebookfa5a3adad6-checkpoint.ipynb
# D:\SberMarket\kaggle_tab_1345\tab_1_orders.csv
# D:\SberMarket\kaggle_tab_1345\tab_3_categories.csv
# D:\SberMarket\kaggle_tab_1345\tab_4_user_profiles.csv
# D:\SberMarket\kaggle_tab_1345\tab_5_product_properties.csv
# D:\SberMarket\sbermarket_tab_2_1\tab_2_products_2020-01-01.csv
# D:\SberMarket\sbermarket_tab_2_1\tab_2_products_2020-01-11.csv
# D:\SberMarket\sbermarket_tab_2_1\tab_2_products_2020-01-21.csv
# D:\SberMarket\sbermarket_tab_2_1\tab_2_products_2020-01-31.csv
# D:\SberMarket\sbermarket_tab_2_1\tab_2_products_2020-02-10.csv
# D:\SberMarket\sbermarket_tab_2_1\tab_2_products_2020-02-20.csv
# ...

# %%
cd D:\SberMarket\kaggle_tab_1345
# Out:
# D:\SberMarket\kaggle_tab_1345

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('tab_1_orders.csv')
df3 = pd.read_csv('tab_3_categories.csv')
df4 = pd.read_csv('tab_4_user_profiles.csv')
df5 = pd.read_csv('tab_5_product_properties.csv')

# %%
cd ..
# Out:
# D:\SberMarket

# %%
df6 = pd.read_csv('tab_6_city.csv')

# %%
cd D:\SberMarket\sbermarket_tab_2_1
# Out:
# D:\SberMarket\sbermarket_tab_2_1

# %%
df2_1_1 = pd.read_csv('tab_2_products_2020-01-01.csv')
df2_1_2 = pd.read_csv('tab_2_products_2020-01-11.csv')
df2_1_3 = pd.read_csv('tab_2_products_2020-01-21.csv')
df2_1_4 = pd.read_csv('tab_2_products_2020-01-31.csv')

# %%
df2_1_1['month']=1
df2_1_1['moment']=1
df2_1_2['month']=1
df2_1_2['moment']=2
df2_1_3['month']=1
df2_1_3['moment']=3
df2_1_4['month']=1
df2_1_4['moment']=4

# %%
df2_2_1 = pd.read_csv('tab_2_products_2020-02-10.csv')
df2_2_2 = pd.read_csv('tab_2_products_2020-02-20.csv')

# %%
df2_2_1['month']=2
df2_2_1['moment']=1
df2_2_2['month']=2
df2_2_2['moment']=3

# %%
df2_3_1 = pd.read_csv('tab_2_products_2020-03-01.csv')
df2_3_2 = pd.read_csv('tab_2_products_2020-03-11.csv')
df2_3_3 = pd.read_csv('tab_2_products_2020-03-21.csv')
df2_3_4 = pd.read_csv('tab_2_products_2020-03-31.csv')

# %%
df2_3_1['month']=3
df2_3_1['moment']=1
df2_3_2['month']=3
df2_3_2['moment']=2
df2_3_3['month']=3
df2_3_3['moment']=3
df2_3_4['month']=3
df2_3_4['moment']=3

# %%
cd D:\SberMarket\sbermarket_tab_2_2
# Out:
# D:\SberMarket\sbermarket_tab_2_2

# %%
df2_4_1 = pd.read_csv('tab_2_products_2020-04-10.csv')
df2_4_2 = pd.read_csv('tab_2_products_2020-04-20.csv')
df2_4_3 = pd.read_csv('tab_2_products_2020-04-30.csv')

# %%
df2_4_1['month']=4
df2_4_1['moment']=1
df2_4_2['month']=4
df2_4_2['moment']=2
df2_4_3['month']=4
df2_4_3['moment']=3

# %%
cd D:\SberMarket\sbermarket_tab_2_3
# Out:
# D:\SberMarket\sbermarket_tab_2_3

# %%
df2_5_1 = pd.read_csv('tab_2_products_2020-05-10.csv')
df2_5_2 = pd.read_csv('tab_2_products_2020-05-20.csv')
df2_5_3 = pd.read_csv('tab_2_products_2020-05-30.csv')

# %%
df2_5_1['month']=5
df2_5_1['moment']=1
df2_5_2['month']=5
df2_5_2['moment']=2
df2_5_3['month']=5
df2_5_3['moment']=3

# %%
cd D:\SberMarket\sbermarket_tab_2_4
# Out:
# D:\SberMarket\sbermarket_tab_2_4

# %%
df2_6_1 = pd.read_csv('tab_2_products_2020-06-09.csv')
df2_6_2 = pd.read_csv('tab_2_products_2020-06-19.csv')
df2_6_3 = pd.read_csv('tab_2_products_2020-06-29.csv')

# %%
df2_6_1['month']=6
df2_6_1['moment']=1
df2_6_2['month']=6
df2_6_2['moment']=2
df2_6_3['month']=6
df2_6_3['moment']=3

# %%
cd D:\SberMarket\sbermarket_tab_2_5
# Out:
# D:\SberMarket\sbermarket_tab_2_5

# %%
df2_7_1 = pd.read_csv('tab_2_products_2020-07-09.csv')
df2_7_2 = pd.read_csv('tab_2_products_2020-07-19.csv')
df2_7_3 = pd.read_csv('tab_2_products_2020-07-29.csv')

# %%
df2_7_1['month']=7
df2_7_1['moment']=1
df2_7_2['month']=7
df2_7_2['moment']=2
df2_7_3['month']=7
df2_7_3['moment']=3

# %%
cd D:\SberMarket\sbermarket_tab_2_6
# Out:
# D:\SberMarket\sbermarket_tab_2_6

# %%
df2_8_1 = pd.read_csv('tab_2_products_2020-08-08.csv')
df2_8_2 = pd.read_csv('tab_2_products_2020-08-18.csv')
df2_8_3 = pd.read_csv('tab_2_products_2020-08-28.csv')
df2_9_1 = pd.read_csv('tab_2_products_2020-09-07.csv')

# %%
df2_8_1['month']=8
df2_8_1['moment']=1
df2_8_2['month']=8
df2_8_2['moment']=2
df2_8_3['month']=8
df2_8_3['moment']=3
df2_9_1['month']=9
df2_9_1['moment']=1

# %%
df2 = pd.concat([df2_1_1,df2_1_2,df2_1_3,df2_1_4,df2_2_1,df2_2_2,df2_3_1,df2_3_2,df2_3_3,df2_3_4,df2_4_1,df2_4_2,df2_4_3,df2_5_1,df2_5_2,df2_5_3,df2_6_1,df2_6_2,df2_6_3,df2_7_1,df2_7_2,df2_7_3,df2_8_1,df2_8_2,df2_8_3,df2_9_1], ignore_index=True)

# %%
df2
# Out:
#           user_id  order_id  line_item_id       price  quantity   discount  \
# 0             525   5354800      28381452  116.000000         4   0.000000
# 1             525   5354800      29242911   56.990002         2  13.080000
# 2             525   5354800      29242919   64.989998         2  40.020000
# 3             525   5354800      29243785   44.990002         6   0.000000
# 4             525   5354800      29244246   65.900002         6  30.990000
# ...           ...       ...           ...         ...       ...        ...
# 59596975  3142966  16654689     173388143   34.889999         1  17.700001
# 59596976  3142966  16654689     173388392   63.889999         1  73.000000
# 59596977  3142966  16654689     173388690   63.889999         1  82.500000
# 59596978  3142966  16654689     173388868  298.489990         1   0.000000
# 59596979  3142966  16654689     173389498  210.589996         1   0.000000
#
# ...

# %%
df2.to_csv('data_2.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2b2309614abe> in <module>
# ----> 1 df2.to_csv('data_2.csv')
#
# NameError: name 'df2' is not defined

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
DataFrame111 = pd.read_csv('data_2.csv')

# %%
DataFrame111
# Out:
#           Unnamed: 0  user_id  order_id  line_item_id       price  quantity  \
# 0                  0      525   5354800      28381452  116.000000         4
# 1                  1      525   5354800      29242911   56.990002         2
# 2                  2      525   5354800      29242919   64.989998         2
# 3                  3      525   5354800      29243785   44.990002         6
# 4                  4      525   5354800      29244246   65.900002         6
# ...              ...      ...       ...           ...         ...       ...
# 59596975    59596975  3142966  16654689     173388143   34.889999         1
# 59596976    59596976  3142966  16654689     173388392   63.889999         1
# 59596977    59596977  3142966  16654689     173388690   63.889999         1
# 59596978    59596978  3142966  16654689     173388868  298.489990         1
# 59596979    59596979  3142966  16654689     173389498  210.589996         1
#
# ...

# %%
DataFrame111[DataFrame111['user_id'] == 51]['product_id'].value_counts().index[:50]
# Out:
# Int64Index([  14863,   19562,   63057, 3562687,     709,    9979, 3817489,
#                 456,     661,    5501,     655,   54728,   54710,     562,
#             6005183,   57399, 3817538,   87007,   50190,     407,    2600,
#             3562686,   46762,   55049,   84364,   84365,   93822,   63724,
#               55133,   16219,       0,    5851,   64633, 3817487,   57398,
#               93825, 5481648,   64216,    7397,   16420,     487,   58839,
#               27471,   56900,   57383,   29788,   58780, 3817571, 7061902,
#             4830888],
#            dtype='int64')

# %%
DataFrame222 = pd.read_csv('sample_submission.csv')

# %%
Id = DataFrame222['Id'].values

# %%
DataFrame111[DataFrame111['user_id'] == 51]['product_id'].value_counts().index[:50]
# Out:
# Int64Index([  14863,   19562,   63057, 3562687,     709,    9979, 3817489,
#                 456,     661,    5501,     655,   54728,   54710,     562,
#             6005183,   57399, 3817538,   87007,   50190,     407,    2600,
#             3562686,   46762,   55049,   84364,   84365,   93822,   63724,
#               55133,   16219,       0,    5851,   64633, 3817487,   57398,
#               93825, 5481648,   64216,    7397,   16420,     487,   58839,
#               27471,   56900,   57383,   29788,   58780, 3817571, 7061902,
#             4830888],
#            dtype='int64')

# %%
dataa = pd.DataFrame(columns=['id']+['pr'+str(i+1) for i in range(50)])

# %%
dataa
# Out:
# Empty DataFrame
# Columns: [id, pr1, pr2, pr3, pr4, pr5, pr6, pr7, pr8, pr9, pr10, pr11, pr12, pr13, pr14, pr15, pr16, pr17, pr18, pr19, pr20, pr21, pr22, pr23, pr24, pr25, pr26, pr27, pr28, pr29, pr30, pr31, pr32, pr33, pr34, pr35, pr36, pr37, pr38, pr39, pr40, pr41, pr42, pr43, pr44, pr45, pr46, pr47, pr48, pr49, pr50]
# Index: []
#
# [0 rows x 51 columns]

# %%
ls=[]
for i in Id:
    
    data = DataFrame111[DataFrame111['user_id'] == i]['product_id'].value_counts().index[:50]
    
    ls.append([i]+list(data))

# %%
dataa = pd.DataFrame(ls, columns=['id']+['pr'+str(i+1) for i in range(50)])

# %%
dataa
# Out:
#              id      pr1        pr2        pr3        pr4        pr5  \
# 0            51    14863    19562.0    63057.0  3562687.0      709.0
# 1            65    54728    18450.0  3817542.0      709.0    26062.0
# 2           766  3043457  3041849.0        0.0  3042629.0  4033676.0
# 3          1132    95465  2599278.0     9970.0    91008.0     2629.0
# 4          1578    22161    19924.0     4513.0    45457.0      304.0
# ...         ...      ...        ...        ...        ...        ...
# 107063  2997849    93412    94112.0        NaN        NaN        NaN
# 107064  2997853    60692  3818078.0      407.0    49921.0  3818498.0
# 107065  2997873  7062001  6210170.0    30361.0    60116.0    24851.0
# 107066  2997988     6590  6692211.0  6003841.0  7392322.0  5479075.0
# 107067  2998048    21757    76069.0    74016.0  6691979.0    29647.0
#
#               pr6        pr7        pr8        pr9  ...       pr41     pr42  \
# ...

# %%
dataa.to_csv('to_submit.csv')

# %%
top_products =  list(DataFrame111['product_id'].value_counts().index[:100])

# %%
import random

# %%
random.choice(top_products)
# Out:
# 3817489

# %%
dataa
# Out:
#              id      pr1        pr2        pr3        pr4        pr5  \
# 0            51    14863    19562.0    63057.0  3562687.0      709.0
# 1            65    54728    18450.0  3817542.0      709.0    26062.0
# 2           766  3043457  3041849.0        0.0  3042629.0  4033676.0
# 3          1132    95465  2599278.0     9970.0    91008.0     2629.0
# 4          1578    22161    19924.0     4513.0    45457.0      304.0
# ...         ...      ...        ...        ...        ...        ...
# 107063  2997849    93412    94112.0        NaN        NaN        NaN
# 107064  2997853    60692  3818078.0      407.0    49921.0  3818498.0
# 107065  2997873  7062001  6210170.0    30361.0    60116.0    24851.0
# 107066  2997988     6590  6692211.0  6003841.0  7392322.0  5479075.0
# 107067  2998048    21757    76069.0    74016.0  6691979.0    29647.0
#
#               pr6        pr7        pr8        pr9  ...       pr41     pr42  \
# ...

# %%
New_data = dataa.fillna(top_products[0])

# %%
New_data
# Out:
#              id      pr1        pr2        pr3        pr4        pr5  \
# 0            51    14863    19562.0    63057.0  3562687.0      709.0
# 1            65    54728    18450.0  3817542.0      709.0    26062.0
# 2           766  3043457  3041849.0        0.0  3042629.0  4033676.0
# 3          1132    95465  2599278.0     9970.0    91008.0     2629.0
# 4          1578    22161    19924.0     4513.0    45457.0      304.0
# ...         ...      ...        ...        ...        ...        ...
# 107063  2997849    93412    94112.0        0.0        0.0        0.0
# 107064  2997853    60692  3818078.0      407.0    49921.0  3818498.0
# 107065  2997873  7062001  6210170.0    30361.0    60116.0    24851.0
# 107066  2997988     6590  6692211.0  6003841.0  7392322.0  5479075.0
# 107067  2998048    21757    76069.0    74016.0  6691979.0    29647.0
#
#               pr6        pr7        pr8        pr9  ...       pr41     pr42  \
# ...

# %%
New_data.to_csv('to_submit5.csv')
